# %%
# %cd /media/Elements/Data/pascal_voc_seg/VOCdevkit/VOC2012/Confidences
# Out:
# /media/Elements/Data/pascal_voc_seg/VOCdevkit/VOC2012/Confidences

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
conf = np.load('2007_000032.npy')

# %%
a = conf*np.iinfo(np.uint16).max
b = a.astype(np.uint16)

# %%
plt.imshow(conf)
plt.show()
plt.draw()

# %%
im = Image.fromarray(b)
im.save('test.png','png')
